# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib_inline

# %%
df = pd.read_csv("/Users/mac/Desktop/Desktop_Files/Projects/Zomato Restaurant Rating Prediction/raw data/zomato.csv")
