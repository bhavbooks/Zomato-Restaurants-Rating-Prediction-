# %% [markdown]
# # 2. Preprocessing and EDA

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
from folium.plugins import FloatImage
import folium # plotting library for maps
from utility.utils import setup_autosave, save_plot

# Plotly
from plotly.offline import init_notebook_mode, iplot, plot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>

# %%
## loading the dataset
import joblib
df = joblib.load("/Users/mac/Desktop/Desktop_Files/Projects/Zomato Restaurant Rating Prediction/artifacts/cleaned_data.pkl")

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost  \
# 0  North Indian, Mughlai, Chinese         800
# 1     Chinese, North Indian, Thai         800
# 2          Cafe, Mexican, Italian         800
# 3      South Indian, North Indian         300
# 4        North Indian, Rajasthani         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
# Changing some columns names for better understanding
df=df.rename(columns={'listed_in(type)':'type','listed_in(city)':'city'})

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost  \
# 0  North Indian, Mughlai, Chinese         800
# 1     Chinese, North Indian, Thai         800
# 2          Cafe, Mexican, Italian         800
# 3      South Indian, North Indian         300
# 4        North Indian, Rajasthani         600
#
#                                         reviews_list menu_item    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []  Buffet
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []  Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari
# 2  Banashankari
# 3  Banashankari
# 4  Banashankari

# %%
# description of the dataset
df.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   url           51717 non-null  object
#  1   address       51717 non-null  object
#  2   name          51717 non-null  object
#  3   online_order  51717 non-null  object
#  4   book_table    51717 non-null  object
#  5   rate          51717 non-null  object
#  6   votes         51717 non-null  int64
#  7   phone         51717 non-null  object
#  8   location      51717 non-null  object
#  9   rest_type     51717 non-null  object
#  10  dish_liked    51717 non-null  object
#  11  cuisines      51717 non-null  object
#  12  approx_cost   51371 non-null  object
#  13  reviews_list  51717 non-null  object
#  14  menu_item     51717 non-null  object
#  15  type          51717 non-null  object
#  16  city          51717 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 6.7+ MB

# %% [markdown]
# #### Dropping Columns that are not required for our analysis
# - phone
# - dish_liked
# - address
# - menu_item
# - city
# - url

# %%
# df.drop(['url','phone','dish_liked','address','menu_item',"city"],axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost  \
# 0  North Indian, Mughlai, Chinese         800
# 1     Chinese, North Indian, Thai         800
# 2          Cafe, Mexican, Italian         800
# 3      South Indian, North Indian         300
# 4        North Indian, Rajasthani         600
#
#                                         reviews_list menu_item    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []  Buffet
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []  Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari
# 2  Banashankari
# 3  Banashankari
# 4  Banashankari

# %%
# df.dropna()

# %%
## appprox_cost missing value imputation with the mean value
df.shape
df['approx_cost'].unique()
df['approx_cost'].nunique()
df['approx_cost'].dtype
# Out:
# dtype('O')

# %%
## changing the datatype of approx_cost to float
df['approx_cost'] = df['approx_cost'].astype(str)
df['approx_cost'] = df['approx_cost'].apply(lambda x: x.replace(',','.'))
df['approx_cost'] = df['approx_cost'].astype(float)

# %% [markdown]
# now, imputatio with the mean would be easy

# %%
## appprox_cost missing value imputation with the mean value
approx_cost_mean = df['approx_cost'].mean()
approx_cost_mean

# filling na with mean value
df['approx_cost'] = df['approx_cost'].fillna(approx_cost_mean)
df['approx_cost'] = df['approx_cost'].astype(int)

# %% [markdown]
# ### Auto saving visualization inside folder->
# from utils.py

# %%
from utility.utils import save_plot, setup_autosave
setup_autosave()
# Out:
# ✅ Auto-save mode activated. Use plt.show('filename') to save automatically.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['approx_cost'], bins=30, kde=True, color='teal', edgecolor='black')
plt.title("Distribution of Approximate Cost", fontsize=14, fontweight='bold')
plt.xlabel("Approx Cost", fontsize=12)
plt.ylabel("Count", fontsize=12)
sns.despine()  # Remove top and right spines for a cleaner look (chatGPT suggestion) 
plt.show('approx_cost_distribution.png')
# Out:
# ✅ Auto-saved: visualizations/approx_cost_distribution.png.png

# %%
## Checking for missing values
df['approx_cost'].isnull().sum()
df[df['approx_cost']==''].shape[0] # done
# Out:
# 0

# %%
## checking for any other missing values in the dataset
df.isnull().sum()
# Out:
# url             0
# address         0
# name            0
# online_order    0
# book_table      0
# rate            0
# votes           0
# phone           0
# location        0
# rest_type       0
# dish_liked      0
# cuisines        0
# approx_cost     0
# reviews_list    0
# menu_item       0
# type            0
# city            0
# dtype: int64

# %%
## checkin for blank values in the dataset
for column in df.columns:
    print(f"{column} : {df[df[column]==''].shape[0]}")
# Out:
# url : 0
# address : 0
# name : 0
# online_order : 0
# book_table : 0
# rate : 7844
# votes : 0
# phone : 1208
# location : 21
# rest_type : 227
# dish_liked : 28078
# cuisines : 45
# approx_cost : 0
# reviews_list : 0
# menu_item : 0
# type : 0
# city : 0

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost', 'reviews_list', 'menu_item', 'type', 'city'],
#       dtype='object')

# %%
## handling "rate" column
df['rate'].unique()
df = df[df['rate'] != 'NEW']
df = df[df['rate'] != ""].reset_index(drop=True)
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5', '4.5/5',
#        '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '3.4 /5',
#        '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5',
#        '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5', '3.5 /5',
#        '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5', '4.3 /5',
#        '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5', '4.9 /5',
#        '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5', '2.1 /5',
#        '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
## also need to remove the "/5" from the rate column values
def remove_slash(data, column):
    removed = lambda x: x.replace('/5', '') if type(x) == str else x
    data[column] = data[column].apply(removed).astype(float)
    return data

# %%
## removing the /5 from rate column using the function
df = remove_slash(df, 'rate')
df['rate'].head() 
## Checking the rate column values after removing /5
df['rate'].unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 2.9, 3.5, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2, 2.3,
#        4.8, 4.9, 2.1, 2. , 1.8])

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['rate'], kde=True, edgecolor='black')
plt.title("Distribution of Restaurant Ratings", fontsize=14)
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show("restaurant_ratings_distribution.png")
# Out:
# ✅ Auto-saved: visualizations/restaurant_ratings_distribution.png.png

# %%
# checking skewness in the rate column
print('skewness->',df.rate.skew()) 
# checking blank values in rate column
df[df['rate']==""].shape[0]
df['rate'].unique()
# Out:
# skewness-> -0.3286007981782886
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 2.9, 3.5, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2, 2.3,
#        4.8, 4.9, 2.1, 2. , 1.8])

# %% [markdown]
# ### Note-> we still have "Blank values" in the dataset that we have replaced for NaN

# %%
## checkin for blank values in the dataset
for column in df.columns:
    print(f"{column} : {df[df[column]==''].shape[0]}")
# Out:
# url : 0
# address : 0
# name : 0
# online_order : 0
# book_table : 0
# rate : 0
# votes : 0
# phone : 814
# location : 0
# rest_type : 149
# dish_liked : 18203
# cuisines : 11
# approx_cost : 0
# reviews_list : 0
# menu_item : 0
# type : 0
# city : 0

# %%
histo = df.groupby('name')['address'].count()
# Lets take the top 50 restaurantsand plot bar graph
histo = histo.sort_values()[-30:]

# %%
# Simple, beautiful, and professional bar plot
# used ChatGPT to beautify the plot->
ax = histo.plot(
    kind='bar',
    figsize=(18, 7),
    rot=75,
    width=0.8,
    color='steelblue',
    edgecolor='black'
)

# Add value labels on bars
for rect in ax.patches:
    ax.text(
        rect.get_x() + rect.get_width() / 2,
        rect.get_height() + 1,
        f'{int(rect.get_height())}',
        ha='center',
        va='bottom',
        fontsize=12,
        color='black'
    )

# Beautify the chart
ax.set_title('Number of Restaurants', fontsize=18, fontweight='bold')
ax.set_xlabel('Restaurant Name', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.set_facecolor('white')
ax.grid(axis='y', linestyle='--', alpha=0.6)

# Simplified legend
ax.legend(['# Restaurants'], fontsize=12, frameon=False)

plt.tight_layout()
plt.show("top_30_restaurants_by_count.png")
# Out:
# ✅ Auto-saved: visualizations/top_30_restaurants_by_count.png.png

# %% [markdown]
# - "Cafe Coffee Day" has literally 86 restaurants in Bengaluru!

# %% [markdown]
# ### Word Cloud

# %%
from wordcloud import WordCloud
## used ChatGPT to beautify the wordcloud plot->
# Generate word cloud from restaurant names
wordcloud = WordCloud(
    width=1600,
    height=800,
    background_color='white',
    colormap='viridis',
    max_words=200,
    relative_scaling=0.5
).generate_from_frequencies(df['name'].value_counts())

# Display the word cloud
plt.figure(figsize=(15, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Most Frequent Restaurant Names", fontsize=18, pad=20)
plt.show("Most Frequent Restaurant Names.png")
# Out:
# ✅ Auto-saved: visualizations/Most Frequent Restaurant Names.png.png

# %% [markdown]
# - Cafe Coffee Day, salute 🫡

# %%
df['approx_cost'].head()
# Out:
# 0    800
# 1    800
# 2    800
# 3    300
# 4    600
# Name: approx_cost, dtype: int64

# %%
plt.figure(figsize=(16,8))

sns.violinplot(
    x='online_order',
    y='approx_cost',
    hue='online_order',
    data=df,
    palette={'Yes':'#1f77b4', 'No':'#ff7f0e'},
    inner='quartile',    # shows median and quartiles
    scale='width',
    legend=False
)

# Plot mean for each category
means = df.groupby('online_order')['approx_cost'].mean()
for i, val in enumerate(means):
    plt.scatter(i, val, color='red', s=100, marker='D', label='Mean' if i==0 else "")

plt.title('Approximate Cost Distribution for 2 People by Online Order Availability', fontsize=20, pad=20)
plt.xlabel('Online Order Available', fontsize=15)
plt.ylabel('Approximate Cost for 2 People (INR)', fontsize=15)
plt.legend()
plt.show("approx_cost_violinplot2")
# Out:
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_1791/1324079509.py:3: FutureWarning:
#
#
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
# ✅ Auto-saved: visualizations/approx_cost_violinplot2.png

# %%
## Violin plot for approx_cost
# used ChatGPT to beautify the violin plot->

plt.figure(figsize=(16,8))
sns.violinplot(
    x=df['approx_cost'],
    color='skyblue',
    inner='quartile',
    scale='width'
)
sns.swarmplot(
    x=df['approx_cost'].sample(500, random_state=42),  # only plot 500 points
    color='darkblue',
    size=3,
    alpha=0.5
)
mean_cost = df['approx_cost'].mean()
plt.axvline(mean_cost, color='red', linestyle='--', linewidth=2, label=f'Mean = {int(mean_cost)}')
plt.title('Distribution of Approximate Cost for 2 People', fontsize=20, pad=20)
plt.xlabel('Approximate Cost for 2 People (INR)', fontsize=15)
plt.ylabel('Density', fontsize=15)
plt.legend()
plt.show("approx_cost_violinplot")
# Out:
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_1791/988911243.py:5: FutureWarning:
#
#
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
# ✅ Auto-saved: visualizations/approx_cost_violinplot.png

# %%
## This code took too long to execute bcz of the swarmplot plotting all points (hence commented it out)
# Swarmplots try to plot every single point individually, and if your dataset is large (thousands of rows), it becomes extremely slow. That’s why plt.show() is hanging.

# plt.figure(figsize=(16,8))
# # used ChatGPT to create a violin plot with boxplot inside
# 
# sns.violinplot(
#     x=df['approx_cost'],
#     color='skyblue',
#     inner='quartile',  # shows median and quartiles
#     density_norm='width'
# )
# 
# # Optional: Overlay a swarmplot to show actual points (small dots)
# sns.swarmplot(
#     x=df['approx_cost'],
#     color='darkblue',
#     size=3,
#     alpha=0.5
# )
# 
# # Add title and axis labels
# plt.title('Distribution of Approximate Cost for 2 People', fontsize=20, pad=20)
# plt.xlabel('Approximate Cost for 2 People (INR)', fontsize=15)
# plt.ylabel('Density', fontsize=15)
# 
# # Annotate mean
# mean_cost = df['approx_cost'].mean()
# plt.axvline(mean_cost, color='red', linestyle='--', linewidth=2, label=f'Mean = {int(mean_cost)}')
# plt.legend()
# 
# plt.show("approx_cost_violinplot")
#

# %% [markdown]
# ## How does various Features affect Rating of the Restaurant

# %% [markdown]
# ### Box Plotting

# %%
#print(df['rate'].unique())
# df.head(2)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def box_plot(df, col, plot_name):
    # Sort categories by median rate
    sorted_vals = df.groupby(col)['rate'].median().sort_values()

    # Plot
    plt.figure(figsize=(15, 8))
    sns.boxplot(x=col, y='rate', data=df, order=sorted_vals.index, palette='crest')

    plt.title(f"Distribution of Ratings by {col.capitalize()}", fontsize=16)
    plt.xlabel(col.capitalize(), fontsize=12)
    plt.ylabel("Rating", fontsize=12)
    plt.xticks(rotation=45)
    plt.tight_layout()

    plt.show(plot_name)
    print(f"Boxplot saved as {plot_name}")

# %%
box_plot(df, 'city', "city_vs_rating_boxplot")
# Out:
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_6885/4284245255.py:10: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# ✅ Auto-saved: visualizations/city_vs_rating_boxplot.png
# Boxplot saved as city_vs_rating_boxplot

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost', 'reviews_list', 'menu_item', 'type', 'city'],
#       dtype='object')

# %% [markdown]
# - bookingg vs restaurant rating

# %%
box_plot(df, 'book_table', plot_name='booking_vs_rating_boxplot')
# Out:
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_1791/4284245255.py:10: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# ✅ Auto-saved: visualizations/booking_vs_rating_boxplot.png
# Boxplot saved as booking_vs_rating_boxplot

# %% [markdown]
# #### finding->
# - Higher Rating leads to Higher Table booking

# %% [markdown]
# Restaurant Type vs Rating BoxPlot

# %%
box_plot(df, 'type', "restaurant_type_vs_rating_boxplot")
# Out:
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_1791/4284245255.py:10: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# ✅ Auto-saved: visualizations/restaurant_type_vs_rating_boxplot.png
# Boxplot saved as restaurant_type_vs_rating_boxplot

# %% [markdown]
# ### Finding->
# - "pubs and bars" restuarants  and "Drinks & nightlife" restaurants have usually higher rating

# %%
box_plot(df, 'online_order', "online_order_vs_rating_boxplot")
# Out:
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_1791/4284245255.py:10: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# ✅ Auto-saved: visualizations/online_order_vs_rating_boxplot.png
# Boxplot saved as online_order_vs_rating_boxplot

# %% [markdown]
# ### Hist Plots

# %% [markdown]
# - Does Rating affect Online Order Quantity?

# %%
## defining hist_plot function
## used ChatGPT to beautify the hist_plot function->
def hist_plot(df, col, plot_name=None, bins=10):
    """
    histogram with KDE for any numeric column.
    """
    # Clean numeric data
    data = pd.to_numeric(df[col], errors='coerce').dropna()
    # Plot
    plt.figure(figsize=(12,6))
    sns.histplot(data, bins=bins, kde=True, color="#3498db", edgecolor='black', alpha=0.7)

    plt.title(f"{col.capitalize()} Distribution", fontsize=16)
    plt.xlabel(col.capitalize())
    plt.ylabel("Count")
    sns.despine()
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show(plot_name)
    print(f"Histogram saved as {plot_name}")

hist_plot(df, 'approx_cost', plot_name='approx_cost_histogram', bins=30)
# Out:
# ✅ Auto-saved: visualizations/approx_cost_histogram.png
# Histogram saved as approx_cost_histogram

# %%
hist_plot(df, 'rate', plot_name='rate_histogram', bins=20)
# Out:
# ✅ Auto-saved: visualizations/rate_histogram.png
# Histogram saved as rate_histogram

# %%
## online_order column is categorical with Yes/No values
## modifying hist_plot function to handle Yes/No categorical data
# plotting histogram for online_order  vs rating
def hist_plot(df, col, plot_name=None, bins=15):
    """
    Simple and beautiful histogram for numeric columns.
    Automatically handles Yes/No categorical data.
    """
    # Handle Yes/No categorical case
    if df[col].dtype == 'object':
        if set(df[col].dropna().unique()) == {'Yes', 'No'}:
            df = df.copy()
            df[col] = df[col].map({'Yes': 1, 'No': 0})
        else:
            print(f"⚠️ '{col}' is non-numeric and not a Yes/No column — skipping.")
            return

    # Convert to numeric safely
    data = pd.to_numeric(df[col], errors='coerce').dropna()

    plt.figure(figsize=(12,6))
    sns.histplot(data, bins=bins, kde=True, color="#2980b9", alpha=0.7, edgecolor='black')

    plt.title(f"{col.capitalize()} Distribution", fontsize=16)
    plt.xlabel(col.capitalize(), fontsize=12)
    plt.ylabel("Count", fontsize=12)
    sns.despine()
    plt.grid(alpha=0.3)
    plt.tight_layout()

    if plot_name is None:
        plot_name = f"hist_{col}.png"
    elif not plot_name.endswith(".png"):
        plot_name += ".png"

    plt.savefig(plot_name)
    plt.show()
    print(f"✅ Histogram saved as '{plot_name}'")

hist_plot(df, 'online_order', plot_name='online_order_histogram', bins=20)
# Out:
# ✅ Histogram saved as 'online_order_histogram.png'

# %% [markdown]
# ### Finding->
# - Weird but Restaurants having rating>4.3 have significantly lower online order count than those having rating within 3 to 4.2
# - maybe the restaurants having rating>4.3 might have higher prices or maybe people think they are fake rating(may be)

# %%
#df.head(2)

# %%
top_votes = df.groupby('name')['votes'].agg(['mean', 'count']).nlargest(10, 'mean')

# Create a figure and axis
fig, ax = plt.subplots(figsize=(6,4))

# Bar plot for top 10 restaurants with largest Votes
bars = sns.barplot(x=top_votes['mean'], y=top_votes.index, palette='Paired', ax=ax)
ax.set(xlabel='Votes', ylabel='Restaurant Name', title='Top 10 Restaurants with Largest Votes')
plt.savefig("top_10_restaurants_votes.png")
# Show the plot
plt.show()
# Out:
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_13248/4032298117.py:7: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# Online order data type change before performing analysis

# %%
df['online_order'].unique()
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost', 'reviews_list', 'menu_item', 'type', 'city'],
#       dtype='object')

# %% [markdown]
# ### Convertingg cateory yes/no to 0/1 for our analysis

# %%
df['book_table'] = df['book_table'].map({'Yes': 1, 'No': 0})

# %%
# Assuming df_clean is your cleaned dataframe
# Step 1: Create rating groups
df['rating_group'] = pd.cut(
    df['rate'],
    bins=[0, 4.2, 5],
    labels=['3 to 4.2', '4.3 and above']
)


df['online_order'] = df['online_order'].map({'Yes': 1, 'No': 0})
# Step 2: Aggregate statistics
group_stats = df.groupby('rating_group').agg({
    'online_order': 'mean',                    # assuming 0/1 for online order
    'approx_cost': 'mean'
}).reset_index()
# Out:
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_1791/528765570.py:12: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
## Trying to find the reason behind the online order count variation with respect to rating
## Finding->
## code logic-chatGPT+ me
# Step: Visualize average cost by rating group
plt.figure(figsize=(10,6))
sns.boxplot(x='rating_group', y='approx_cost', data=df, palette='pastel')
plt.title("Price Distribution by Rating Group", fontsize=16)
plt.xlabel("Rating Group", fontsize=12)
plt.ylabel("Average Cost for Two", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine()
plt.show()

# Step: Visualize online order proportion by rating group
plt.figure(figsize=(8,5))
sns.barplot(x='rating_group', y='online_order', data=df, palette='muted')
plt.title("Proportion of Online Orders by Rating Group", fontsize=16)
plt.xlabel("Rating Group", fontsize=12)
plt.ylabel("Proportion of Online Orders", fontsize=12)
plt.ylim(0,1)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine()
plt.show()


# Step: Optional: Boxplot of ratings vs online order availability
plt.figure(figsize=(10,6))
sns.boxplot(x='online_order', y='rate', data=df, palette='cool')
plt.title("Rating Distribution by Online Order Availability", fontsize=16)
plt.xlabel("Online Order (0=No, 1=Yes)", fontsize=12)
plt.ylabel("Rating", fontsize=12)
sns.despine()
plt.show()
# Out:
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_1791/590749209.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_1791/590749209.py:17: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_1791/590749209.py:30: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
hist_plot(df, 'online_order', "online_order_distribution.png")
# Out:
# ✅ Histogram saved as 'online_order_distribution.png'

# %%
df.head(1)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
#
#                                              address   name  online_order  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa             1
#
#    book_table  rate  votes                           phone      location  \
# 0           1   4.1    775  080 42297555\r\n+91 9743772233  Banashankari
#
#        rest_type                                         dish_liked  \
# 0  Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
#
#                          cuisines  approx_cost  \
# 0  North Indian, Mughlai, Chinese          800
#
#                                         reviews_list menu_item    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
#
#            city rating_group
# 0  Banashankari     3 to 4.2

# %%
with plt.style.context('bmh', after_reset = True):
    plt.figure(figsize = (12,4))
    ax = plt.subplot(1,1,1)
    tmp = {}
    for col in ['online_order', 'book_table']: 
        tmp[col] = df[col].value_counts()
    tmp = pd.DataFrame.from_dict(tmp, orient = 'index')
    tmp.plot.barh(stacked = True, ax = ax)
    ax.set_title('Fraction of Delivery and Book Table')
    plt.show("delivery_booktable_fraction")
# Out:
# ✅ Auto-saved: visualizations/delivery_booktable_fraction.png

# %%
# Pie chart showing Zomato's presence in various locations of Bangalore
# used ChatGPT to beautify the pie chart->

# labels = list(df.location.value_counts().index)
# values = list(df.location.value_counts().values)
# 
# fig = {
#     "data":[
#         {
#             "labels" : labels,
#             "values" : values,
#             "hoverinfo" : 'label+percent',
#             "domain": {"x": [0, .9]},
#             "hole" : 0.6,
#             "type" : "pie",
#             "rotation":120,
#         },
#     ],
#     "layout": {
#         "title" : "Zomato's Presence in Bangalore",
#         "annotations": [
#             {
#                 "font": {"size":20},
#                 "showarrow": True,
#                 "text": "Neighborhood",
#                 "x":0.2,
#                 "y":0.9,
#             },
#         ]
#     }
# }
# 
# plot(fig)

# %% [markdown]
# ## Map

# %% [markdown]
# ### Getting coordinates from location column

# %% [markdown]
# - 🛑 this code might take a bit longer to execute as this goes through every address and searches for it and then gets the coordinates accordingly

# %%
## Zomato Presence across Bangalore
# used chatGPT to debug


## coordinates of Bangalore->
from geopy.geocoders import Nominatim # ''' Nominatim is a free geocoding service from OpenStreetMap — it converts human-readable locations (like “Koramangala, Bengaluru”) into latitude and longitude coordinates. '''
location = [x for x in df['location'].unique().tolist() if type(x) == str]
latitude = []
longitude =  []
for i in range(0, len(location)):
    if(type(location[i]) == str):
        ctr=0
        while True:
            try:
                address = location[i] + ', Bengaluru, India'
                geolocator = Nominatim(user_agent="ny_explorer") #This is the actual API call to OpenStreetMap’s Nominatim service.
                '''It searches for “Indiranagar, Bengaluru, India” If found, it returns a location object with: numerical latitude and longitude coordinates.'''
                loc = geolocator.geocode(address)
                latitude.append(loc.latitude)
                longitude.append(loc.longitude)
                print('The geograpical coordinate of location are {}, {}.'.format(loc.latitude, loc.longitude))
            except:
                ctr+=1
                if(ctr==7):
                    print(i)
                    latitude.append(address)
                    longitude.append(address)
                    break
                continue
            break
# Out:
# The geograpical coordinate of location are 12.9278196, 77.556621.
# The geograpical coordinate of location are 12.9417261, 77.5755021.
# The geograpical coordinate of location are 12.9467026, 77.5300705.
# The geograpical coordinate of location are 12.9292731, 77.5824229.
# The geograpical coordinate of location are 12.9067683, 77.5595021.
# The geograpical coordinate of location are 12.9274413, 77.5155224.
# The geograpical coordinate of location are 12.9660726, 77.6125941.
# The geograpical coordinate of location are 12.9055682, 77.5455438.
# The geograpical coordinate of location are 12.9096941, 77.5866067.
# The geograpical coordinate of location are 12.9287596, 77.6287122.
# The geograpical coordinate of location are 12.965718, 77.5762705.
# The geograpical coordinate of location are 12.8551298, 77.5886808.
# The geograpical coordinate of location are 12.9112759, 77.6045654.
# The geograpical coordinate of location are 12.8983024, 77.5719586.
# The geograpical coordinate of location are 12.9089453, 77.6239038.
# The geograpical coordinate of location are 12.8487599, 77.648253.
# The geograpical coordinate of location are 12.9246491, 77.6382779.
# The geograpical coordinate of location are 12.9489339, 77.5968273.
# The geograpical coordinate of location are 12.9555367, 77.5924278.
# The geograpical coordinate of location are 12.9348429, 77.6189768.
# The geograpical coordinate of location are 12.9684808, 77.614415.
# The geograpical coordinate of location are 12.9116225, 77.6388622.
# The geograpical coordinate of location are 12.9364846, 77.6134783.
# The geograpical coordinate of location are 12.9371445, 77.6720227.
# The geograpical coordinate of location are 12.9552572, 77.6984163.
# The geograpical coordinate of location are 12.9963995, 77.7614229.
# The geograpical coordinate of location are 12.9725571, 77.7116049.
# The geograpical coordinate of location are 12.9572062, 77.6741501.
# The geograpical coordinate of location are 12.9732913, 77.6404672.
# The geograpical coordinate of location are 12.9277245, 77.6327822.
# The geograpical coordinate of location are 12.9975851, 77.6136744.
# The geograpical coordinate of location are 12.9755264, 77.6067902.
# The geograpical coordinate of location are 12.9673575, 77.6064353.
# The geograpical coordinate of location are 12.9712421, 77.5979738.
# The geograpical coordinate of location are 12.9754985, 77.6026657.
# The geograpical coordinate of location are 12.9778793, 77.6246697.
# The geograpical coordinate of location are 12.9692682, 77.6022207.
# The geograpical coordinate of location are 12.9855286, 77.6054496.
# The geograpical coordinate of location are 12.9800059, 77.6050006.
# The geograpical coordinate of location are 12.9758014, 77.6016924.
# The geograpical coordinate of location are 12.9884255, 77.5938978.
# The geograpical coordinate of location are 12.983826, 77.5851733.
# The geograpical coordinate of location are 12.9822423, 77.608265.
# The geograpical coordinate of location are 12.9921738, 77.591459.
# The geograpical coordinate of location are 12.9624669, 77.6381958.
# The geograpical coordinate of location are 12.9408685, 77.617338.
# The geograpical coordinate of location are 12.945245, 77.6274776.
# The geograpical coordinate of location are 12.9678074, 77.6568367.
# The geograpical coordinate of location are 13.0069424, 77.6885153.
# The geograpical coordinate of location are 12.9931876, 77.5753419.
# The geograpical coordinate of location are 13.0148544, 77.6382029.
# The geograpical coordinate of location are 12.9390255, 77.6238477.
# The geograpical coordinate of location are 12.9779079, 77.5723936.
# The geograpical coordinate of location are 12.957998, 77.6037312.
# The geograpical coordinate of location are 12.9730087, 77.5804711.
# The geograpical coordinate of location are 12.9652094, 77.717936.
# 56
# The geograpical coordinate of location are 12.9617173, 77.7479186.
# The geograpical coordinate of location are 12.9243692, 77.6242433.
# The geograpical coordinate of location are 12.9282918, 77.6254034.
# The geograpical coordinate of location are 12.9327778, 77.6294052.
# The geograpical coordinate of location are 12.9357366, 77.624081.
# The geograpical coordinate of location are 12.9344111, 77.6123882.
# The geograpical coordinate of location are 13.0227204, 77.595715.
# The geograpical coordinate of location are 13.0141618, 77.6518539.
# The geograpical coordinate of location are 13.0222347, 77.5671832.
# The geograpical coordinate of location are 13.0422794, 77.6248577.
# The geograpical coordinate of location are 13.037077, 77.6413572.
# The geograpical coordinate of location are 13.0221416, 77.6403368.
# The geograpical coordinate of location are 13.031992, 77.6280789.
# 70
# The geograpical coordinate of location are 12.973936, 77.6509982.
# The geograpical coordinate of location are 12.9850987, 77.6631173.
# The geograpical coordinate of location are 12.9830404, 77.6773956.
# The geograpical coordinate of location are 12.9176571, 77.4837568.
# The geograpical coordinate of location are 13.0041747, 77.5828354.
# The geograpical coordinate of location are 13.0027353, 77.5703253.
# The geograpical coordinate of location are 12.9578658, 77.6958748.
# 78
# The geograpical coordinate of location are 12.9911804, 77.5448918.
# The geograpical coordinate of location are 13.0005232, 77.5496166.
# The geograpical coordinate of location are 13.0221838, 77.5530824.
# The geograpical coordinate of location are 13.039186, 77.564284.
# The geograpical coordinate of location are 13.0222347, 77.5671832.
# The geograpical coordinate of location are 12.975608, 77.5553564.
# The geograpical coordinate of location are 13.1006982, 77.5963454.
# The geograpical coordinate of location are 13.0621474, 77.5800614.
# The geograpical coordinate of location are 13.0394104, 77.5197351.
# The geograpical coordinate of location are 13.0382184, 77.5919.
# The geograpical coordinate of location are 12.9651215, 77.5090098.
# The geograpical coordinate of location are 13.0330515, 77.5332233.
# The geograpical coordinate of location are 13.007516, 77.695935.

# %% [markdown]
# ### Getting coordinated from the location column

# %%
df['location_latitude'] = df['location'].map(dict(zip(location, latitude)))
df['location_longitude'] = df['location'].map(dict(zip(location, longitude)))

# %%
for lat in df['location_latitude'].unique():
    if type(lat) == str:
        df = df[df['location_latitude'] != lat]

for lng in df['location_longitude'].unique():
    if type(lng) == str:
        df = df[df['location_longitude'] != lng]
df['location_latitude'] = df['location_latitude'].astype(float)
df['location_longitude'] = df['location_longitude'].astype(float)

# %%
df['location_latitude'].unique()
# Out:
# array([12.9278196, 12.9417261, 12.9466619, 12.9292731, 12.9067683,
#        12.9274413, 12.9660726, 12.9055682, 12.9096941, 12.9287596,
#        12.965718 , 12.9453394, 12.9112759, 12.8818988, 12.9089453,
#        12.8487599, 12.9241545, 12.9489339, 12.9555367, 12.9348429,
#        12.9650665, 12.9116225, 12.9364846, 12.9361208, 12.9552572,
#        12.9963995, 12.9608284, 12.9592288, 12.9732913, 12.9277245,
#        12.9975851, 12.9755264, 12.9674073, 12.9749682, 12.9746938,
#        12.9778793, 12.9692682, 12.9855286, 12.9810155, 12.9758014,
#        12.9907797, 12.9819637, 12.9822423, 12.9921738, 12.9624669,
#        12.9408685, 12.945245 , 12.9678074, 13.0179099, 12.9931876,
#        13.0148544, 12.9390255, 12.9779079, 12.957998 , 12.9730087,
#        12.9652094, 12.9625188, 12.9243692, 12.9282918, 12.9327778,
#        12.9357366, 12.9614145, 13.0227204, 13.0141618, 13.0222347,
#        13.0529146, 13.037077 , 13.0221416, 13.031992 , 12.973936 ,
#        12.9850987, 12.9846713, 12.9176571, 12.9878064, 13.0027353,
#        12.9578658, 12.9911804, 13.0005232, 13.0221838, 13.039186 ,
#        12.975608 , 13.1006982, 13.0621474, 13.0394104, 13.0382184,
#        12.9651215, 13.0330515, 13.007516 ])

# %%
df.groupby(['location'])['rate'].mean().sort_values()[-50:][:-1]
# Out:
# location
# Hebbal                   3.600000
# Vijay Nagar              3.604687
# Frazer Town              3.614912
# Rajajinagar              3.615401
# Whitefield               3.621618
# Central Bangalore        3.625000
# Sahakara Nagar           3.633333
# Yelahanka                3.640000
# Basaveshwara Nagar       3.646715
# Banashankari             3.649866
# Old Airport Road         3.654190
# Mysore Road              3.658824
# Kammanahalli             3.667465
# Basavanagudi             3.671092
# HSR                      3.672164
# JP Nagar                 3.675306
# HBR Layout               3.676768
# Vasanth Nagar            3.683265
# Sarjapur Road            3.686143
# New BEL Road             3.688976
# Koramangala 1st Block    3.696831
# Seshadripuram            3.704930
# Brigade Road             3.705228
# Kengeri                  3.722222
# Koramangala              3.726667
# Koramangala 8th Block    3.731897
# Koramangala 2nd Block    3.749425
# Ulsoor                   3.758304
# Malleshwaram             3.759657
# Koramangala 6th Block    3.778087
# Jayanagar                3.780280
# Kalyan Nagar             3.781948
# Race Course Road         3.782222
# Hosur Road               3.790278
# Infantry Road            3.796429
# Langford Town            3.807407
# Richmond Road            3.820588
# Indiranagar              3.828154
# Rajarajeshwari Nagar     3.850000
# Koramangala 7th Block    3.850377
# MG Road                  3.855857
# Residency Road           3.863636
# Cunningham Road          3.901053
# Koramangala 4th Block    3.918668
# Sankey Road              3.965385
# Church Street            3.992125
# Koramangala 5th Block    4.005821
# St. Marks Road           4.017201
# Koramangala 3rd Block    4.020419
# Name: rate, dtype: float64

# %%
## Map of Zomato's restaurant locations in Bangalore
# Create a map centered around Bangalore

dataframe_filtered = df.groupby(['location'])[['location_latitude', 'location_longitude']].first()
dataframe_filtered['no_restaurant'] = df.groupby(['location'])['url'].count()
venues_map = folium.Map(location=[12.934533, 77.626579], zoom_start=11) # generate map centred around Bengaluru

states = folium.map.FeatureGroup()
i=0
for lat, lng, in zip(dataframe_filtered.location_latitude, dataframe_filtered.location_longitude):
    states.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6,
        )
    )
    i+=1
i=0
for lat, lng, in zip(dataframe_filtered.location_latitude, dataframe_filtered.location_longitude):
    states.add_child(
        folium.features.Marker(
            [lat, lng],
            popup= dataframe_filtered.index[i],
        )
    )
    i+=1
# add incidents to map
venues_map.add_child(states)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee4fd423c8adea279b437dafb32997dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee4fd423c8adea279b437dafb32997dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee4fd423c8adea279b437dafb32997dc = L.map(
#                 &quot;map_ee4fd423c8adea279b437dafb32997dc&quot;,
#                 {
#                     center: [12.934533, 77.626579],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9297a772c597f7397beace2ff5d00663 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9297a772c597f7397beace2ff5d00663.addTo(map_ee4fd423c8adea279b437dafb32997dc);
#
#
#             var feature_group_50222b7ad09d14d33f42c548e118897a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_6e2e21445b2520f2a55a4a91a676444c = L.circleMarker(
#                 [12.9112759, 77.6045654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_50222b7ad09d14d33f42c548e118897a);
#
#
#             var circle_marker_91279d600f390098b24d7db04101821a = L.circleMarker(
#                 [12.9278196, 77.556621],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_50222b7ad09d14d33f42c548e118897a);
#
#
#             var circle_marker_4ece10530f75b641d5b1961452395a84 = L.circleMarker(
#                 [13.0141618, 77.6518539],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_50222b7ad09d14d33f42c548e118897a);
#
#
#             var circle_marker_d3aef8f94669f1f9f83f7324e55c09aa = L.circleMarker(
#                 [12.9453394, 77.6025834],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_50222b7ad09d14d33f42c548e118897a);
#
#
#             var circle_marker_8bfaa620b872e1880b1603d19469691e = L.circleMarker(
#                 [12.9417261, 77.5755021],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_50222b7ad09d14d33f42c548e118897a);
#
#
#             var circle_marker_8e6f05c2430c8551dd139d9dd62e1674 = L.circleMarker(
#                 [12.9911804, 77.5448918],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot

# %%
print(df.columns)
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost', 'reviews_list', 'menu_item', 'type', 'city',
#        'rating_group', 'location_latitude', 'location_longitude'],
#       dtype='object')

# %% [markdown]
# ### (Map) Bubble based on the number of Restaurants

# %%
dataframe_filtered = (
    df.groupby('location')
      .agg({'location_latitude': 'first', 'location_longitude': 'first', 'url': 'count'})
      .rename(columns={'url': 'no_restaurant'})
)

venues_map = folium.Map(location=[12.9716, 77.5946], zoom_start=11)

for idx, row in dataframe_filtered.iterrows():
    folium.CircleMarker(
        location=[float(row['location_latitude']), float(row['location_longitude'])],
        radius=5 + row['no_restaurant'] * 0.01,  # bubble size based on restaurant count
        color='blue',
        fill=True,
        fill_color='lightblue',
        fill_opacity=0.6,
        popup=f"{idx} — {row['no_restaurant']} restaurants"
    ).add_to(venues_map)

venues_map.save("bangalore_restaurants_map.html")
print("✅ Map saved as 'bangalore_restaurants_map.html'")
venues_map
# Out:
# ✅ Map saved as 'bangalore_restaurants_map.html'
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c525e733fd2ec7d3df2ead51d738bf8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c525e733fd2ec7d3df2ead51d738bf8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c525e733fd2ec7d3df2ead51d738bf8f = L.map(
#                 &quot;map_c525e733fd2ec7d3df2ead51d738bf8f&quot;,
#                 {
#                     center: [12.9716, 77.5946],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f02807bba5fa15f446bc4dc372a8be5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f02807bba5fa15f446bc4dc372a8be5.addTo(map_c525e733fd2ec7d3df2ead51d738bf8f);
#
#
#             var circle_marker_14f4756df8b0c0e31b67dc9d37bde1db = L.circleMarker(
#                 [12.9112759, 77.6045654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 44.300000000000004, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c525e733fd2ec7d3df2ead51d738bf8f);
#
#
#         var popup_cbfa200e7ec1622614bd2245050fb2de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_218b48c8f3a399eec51d313ba15865ee = $(`&lt;div id=&quot;html_218b48c8f3a399eec51d313ba15865ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BTM — 3930.0 restaurants&lt;/div&gt;`)[0];
#                 popup_cbfa200e7ec1622614bd2245050fb2de.setContent(html_218b48c8f3a399eec51d313ba15865ee);
#
#
#
#         circle_marker_14f4756df8b0c0e31b67dc9d37bde1db.bindPopup(popup_cbfa200e7ec1622614bd2245050fb2de)
#         ;
#
#
#
#
#             var circle_marker_c612fa33cc18319112845fbd9c646b1b = L.circleMarker(
#                 [12.9278196, 77.556621],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12.440000000000001, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c525e733fd2ec7d3df2ead51d738bf8f);
#
#
#         var popup_825845ee89dff14c439e020f81db9ef0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f6fce00744499525d29cdf5b2a00eb1 = $(`&lt;div id=&quot;html_7f6fce00744499525d29cdf5b2a00eb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Banashankari — 744.0 restaurants&lt;/div&gt;`)[0];
#                 popup_825845ee89dff14c439e020f81db9ef0.setContent(html_7f6fce00744499525d29cdf5b2a00eb1);
#
#
#
#         circle_marker_c612fa33cc18319112845fbd9c646b1b.bindPopup(popup_825845ee89dff14c439e020f81db9ef0)
#         ;
#
#
#
#
#             var circle_marker_69910321ce7f6518f24326552872205a = L.circleMarker(
#                 [13.0141618, 77.6518539],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c525e733fd2ec7d3df2ead51d738bf8f);
#
#
#         var popup_6cebb8a65ccf2f2bebd3f6033515b58d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_899064021cd7764f8f78916c2c2e5415 = $(`&lt;div id=&quot;html_899064021cd7764f8f78916c2c2e5415&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Banaswadi — 480.0 restaurants&lt;/div&gt;`)[0];
#                 popup_6cebb8a65ccf2f2bebd3f6033515b58d.setContent(html_899064021cd7764f8f78916c2c2e5415);
#
#
#
#         circle_marker_69910321ce7f6518f24326552872205a.bindPopup(popup_6cebb8a65ccf2f2bebd3f6033515b58d)
#         ;

# %%
## trying to Clean Cuisine column for better analysis
columns = ['cuisine', 'Total Restaurants', 'rate']
df_cuisine = pd.DataFrame(columns = columns) 

# creating a dataframe to store cuisine, total restaurants having that cuisine and average rate of that cuisine

for cuisine in df['cuisines'].unique():
    # DataFrame' object has no attribute 'append' (got to know from Error message🙂)
    df_cuisine = pd.concat([df_cuisine, pd.DataFrame({'cuisine': [cuisine],
                                                       'Total Restaurants': [df[df['cuisines'] == cuisine].shape[0]],
                                                       'rate': [df[df['cuisines'] == cuisine]['rate'].mean()]})], ignore_index=True)
# Out:
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_1791/3671295783.py:9: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %%
df_cuisine.head() # done
# Out:
#                           cuisine Total Restaurants      rate
# 0  North Indian, Mughlai, Chinese                89  3.344944
# 1     Chinese, North Indian, Thai                 8  3.750000
# 2          Cafe, Mexican, Italian                11  3.800000
# 3      South Indian, North Indian               220  3.528636
# 4        North Indian, Rajasthani                 8  3.875000

# %% [markdown]
# ### Let us ifnd the cuisines that has averae rating of >4. -> (Personal Curiosity)

# %%
df_cuisine[df_cuisine['rate'] > 4].head(10).sort_values(by='rate', ascending=False) # also sorted by rate
# Out:
#                                               cuisine Total Restaurants  \
# 7                                Pizza, Cafe, Italian                85
# 9            Cafe, Mexican, Italian, Momos, Beverages                 7
# 51                     Italian, North Indian, Mexican                 5
# 48  Asian, Korean, Indonesian, Japanese, Chinese, ...                 6
# 56  Continental, Italian, Mexican, North Indian, C...                 6
# 59                            Biryani, Chinese, Kebab                 2
# 15                            Cafe, Italian, American                16
# 32       North Indian, Mughlai, South Indian, Chinese                56
# 8                          Cafe, Italian, Continental                34
# 50                                Desserts, Beverages               247
#
#         rate
# 7   4.410588
# 9   4.200000
# 51  4.200000
# 48  4.200000
# 56  4.100000
# 59  4.100000
# 15  4.100000
# 32  4.094643
# 8   4.073529
# 50  4.066397

# %% [markdown]
# - Pizza, Cafe, Italian, Mexican, Momos, North Indian etc are the top cuisines

# %%
df_cuisine[df_cuisine['rate'] > 4].head(10).sort_values(by='Total Restaurants', ascending=False) # also sorted by rate
# Out:
#                                               cuisine Total Restaurants  \
# 50                                Desserts, Beverages               247
# 7                                Pizza, Cafe, Italian                85
# 32       North Indian, Mughlai, South Indian, Chinese                56
# 8                          Cafe, Italian, Continental                34
# 15                            Cafe, Italian, American                16
# 9            Cafe, Mexican, Italian, Momos, Beverages                 7
# 48  Asian, Korean, Indonesian, Japanese, Chinese, ...                 6
# 56  Continental, Italian, Mexican, North Indian, C...                 6
# 51                     Italian, North Indian, Mexican                 5
# 59                            Biryani, Chinese, Kebab                 2
#
#         rate
# 50  4.066397
# 7   4.410588
# 32  4.094643
# 8   4.073529
# 15  4.100000
# 9   4.200000
# 48  4.200000
# 56  4.100000
# 51  4.200000
# 59  4.100000

# %% [markdown]
# - Desserts, Beverages cuisines has highest number of restaurants in Bengaluru.
# - 247 restaurants!!

# %%
df_cuisine['Total Restaurants'].sum()
# Out:
# 41665

# %%
# Filtering & plotting top cuisines
df_cuisine = df_cuisine[df_cuisine['Total Restaurants'] > 900] # Taking cuisines that are atleast served in over 900 restaurants 
# bar plot for top cuisines
# used ChatGPT to beautify the bar plot
def bar_plot(df, x_col, y_col, plot_name):
    plt.figure(figsize=(12,6))
    sns.barplot(x=x_col, y=y_col, data=df, palette='viridis', edgecolor='black')
    plt.title("Top Cuisines by Number of Restaurants", fontsize=16)
    plt.xlabel("Cuisine", fontsize=12)
    plt.ylabel("Total Restaurants", fontsize=12)
    plt.xticks(rotation=45)
    sns.despine()
    plt.tight_layout()
    plt.show(plot_name)
    print(f"Bar plot saved as {plot_name}")
bar_plot(df_cuisine, "cuisine", "Total Restaurants", "top_cuisines")
# Out:
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_1791/2361495990.py:7: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# ✅ Auto-saved: visualizations/top_cuisines.png
# Bar plot saved as top_cuisines

# %%
## polar plot for cuisines vs rating->
# used ChatGPT to beautify the polar plot->
def polar_plot(df, category_col, value_col, plot_name):
    plt.figure(figsize=(10,10))
    ax = plt.subplot(111, polar=True)
    
    # Number of categories
    num_vars = len(df[category_col])
    
    # Compute angle for each category
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
    
    # The values to plot
    values = df[value_col].tolist()
    values += values[:1]  # Complete the loop
    
    angles += angles[:1]  # Complete the loop
    
    # Plot data
    ax.fill(angles, values, color='teal', alpha=0.25)
    ax.plot(angles, values, color='teal', linewidth=2)
    
    # Add category labels
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(df[category_col], fontsize=12)
    
    # Add title and labels
    plt.title(f"{value_col.capitalize()} by {category_col.capitalize()}", size=16, y=1.1)
    
    plt.tight_layout()
    plt.show(plot_name)
    print(f"Polar plot saved as {plot_name}")

# %%
polar_plot(df_cuisine, 'cuisine', 'rate', 'cuisine_vs_rating_polar_plot')
# Out:
# ✅ Auto-saved: visualizations/cuisine_vs_rating_polar_plot.png
# Polar plot saved as cuisine_vs_rating_polar_plot

# %% [markdown]
# ### North Indian, South Indian, Chinese cuisines dominate over entire Bengalore!

# %%
## savingg new cleaned dataframe
import joblib
joblib.dump(df.reset_index(drop=True), "/Users/mac/Desktop/Desktop_Files/Projects/Zomato Restaurant Rating Prediction/artifacts/EDA_cleaned.pkl") # I've saved the cleaned dataframe after EDA for future use
# Out:
# ['/Users/mac/Desktop/Desktop_Files/Projects/Zomato Restaurant Rating Prediction/artifacts/EDA_cleaned.pkl']

# %% [markdown]
# ### More Cuisines Analysis

# %% [markdown]
# Grouping the neighborhood by the cuisines
# Is there any neighborhood that is more famous for its cuisines

# %%
types = set()
def func(x):
    if(type(x) == list):
        for y in x:
            types.add(y.strip())
_ = df['cuisines'].str.split(',').apply(func)

# %%
column_names = list(types)
# instantiate the dataframe
neighborhood_cns = pd.DataFrame(columns=column_names)
neighborhood_cns
# Out:
# Empty DataFrame
# Columns: [, Goan, Wraps, Japanese, Tex-Mex, Burmese, Indonesian, Iranian, Charcoal Chicken, Sri Lankan, Pizza, Mongolian, Andhra, Konkan, Tea, Mediterranean, Awadhi, South American, Spanish, North Indian, Salad, Bubble Tea, Oriya, BBQ, Modern Indian, Gujarati, Mithai, Kebab, Coffee, Lebanese, Assamese, Greek, Rajasthani, Singaporean, Afghani, Bohri, Roast Chicken, Sandwich, Parsi, Italian, Paan, Mughlai, Pan Asian, Raw Meats, Seafood, Maharashtrian, Hyderabadi, Finger Food, Cafe, French, Lucknowi, South Indian, Tibetan, German, Chinese, American, Bihari, Biryani, Cantonese, Chettinad, Kashmiri, Middle Eastern, Bengali, Burger, Juices, Healthy Food, Kerala, Mexican, Belgian, Sindhi, Afghan, Desserts, Tamil, Turkish, Sushi, Steak, Vietnamese, Malaysian, Fast Food, European, Portuguese, Beverages, North Eastern, Drinks Only, Momos, Jewish, Korean, Nepalese, Vegan, Russian, Street Food, Rolls, African, Thai, Asian, British, Naga, Bakery, Australian, Continental, ...]
# Index: []
#
# [0 rows x 106 columns]

# %%
neighborhood_cns['neighborhood'] = df.groupby('location').groups.keys()
neighborhood_cns = neighborhood_cns.set_index('neighborhood').fillna(0)
neighborhood_cns
# Out:
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_1791/330194574.py:2: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#                       Goan  Wraps  Japanese  Tex-Mex  Burmese  Indonesian  \
# neighborhood
# BTM                0     0      0         0        0        0           0
# Banashankari       0     0      0         0        0        0           0
# Banaswadi          0     0      0         0        0        0           0
# Bannerghatta Road  0     0      0         0        0        0           0
# Basavanagudi       0     0      0         0        0        0           0
# ...               ..   ...    ...       ...      ...      ...         ...
# West Bangalore     0     0      0         0        0        0           0
# Whitefield         0     0      0         0        0        0           0
# Wilson Garden      0     0      0         0        0        0           0
# Yelahanka          0     0      0         0        0        0           0
# Yeshwantpur        0     0      0         0        0        0           0
#
#                    Iranian  Charcoal Chicken  Sri Lankan  ...  Naga  Bakery  \
# neighborhood                                              ...
# BTM                      0                 0           0  ...     0       0
# Banashankari             0                 0           0  ...     0       0
# Banaswadi                0                 0           0  ...     0       0
# Bannerghatta Road        0                 0           0  ...     0       0
# Basavanagudi             0                 0           0  ...     0       0
# ...                    ...               ...         ...  ...   ...     ...
# West Bangalore           0                 0           0  ...     0       0
# Whitefield               0                 0           0  ...     0       0
# Wilson Garden            0                 0           0  ...     0       0
# Yelahanka                0                 0           0  ...     0       0
# Yeshwantpur              0                 0           0  ...     0       0
#
#                    Australian  Continental  Grill  Ice Cream  Hot dogs  \
# neighborhood
# BTM                         0            0      0          0         0
# Banashankari                0            0      0          0         0
# Banaswadi                   0            0      0          0         0
# Bannerghatta Road           0            0      0          0         0
# Basavanagudi                0            0      0          0         0
# ...                       ...          ...    ...        ...       ...
# West Bangalore              0            0      0          0         0
# Whitefield                  0            0      0          0         0
# Wilson Garden               0            0      0          0         0
# Yelahanka                   0            0      0          0         0
# Yeshwantpur                 0            0      0          0         0
#
#                    Arabian  Mangalorean  Bar Food
# neighborhood
# BTM                      0            0         0
# Banashankari             0            0         0
# Banaswadi                0            0         0
# Bannerghatta Road        0            0         0
# Basavanagudi             0            0         0
# ...                    ...          ...       ...
# West Bangalore           0            0         0
# Whitefield               0            0         0
# Wilson Garden            0            0         0
# Yelahanka                0            0         0
# Yeshwantpur              0            0         0
#
# [92 rows x 106 columns]

# %%
from sklearn.preprocessing import MultiLabelBinarizer
# Split the cuisines by comma and convert to list
df['cuisines_list'] = df['cuisines'].fillna('').apply(lambda x: [c.strip() for c in x.split(',') if c.strip() != ''])

# Initialize MultiLabelBinarizer (chatGPT suggestion for faster one-hot encoding)
mlb = MultiLabelBinarizer()
cuisine_dummies = pd.DataFrame(mlb.fit_transform(df['cuisines_list']),
                               columns=mlb.classes_,
                               index=df.index)

# Group by location and sum the counts
neighborhood_cns = df[['location']].join(cuisine_dummies)
neighborhood_cns = neighborhood_cns.groupby('location').sum()

# Optional: order columns alphabetically (or by your 'types' list if you want)
neighborhood_cns = neighborhood_cns[sorted(neighborhood_cns.columns)]

# Display
print(neighborhood_cns.head())
# Out:
#                    Afghan  Afghani  African  American  Andhra  Arabian  Asian  \
# location
# BTM                    11        0        0        27     154      185     39
# Banashankari            0        0        0         4       8        2      6
# Banaswadi               0        0        0         0      34       10      2
# Bannerghatta Road       0        0        8        30      55       40     13
# Basavanagudi            0        0        0         0      14        0     10
#
#                    Assamese  Australian  Awadhi  ...  Sushi  Tamil  Tea  \
# location                                         ...
# BTM                       0           0       0  ...      0      0   31
# Banashankari              0           0       0  ...      0      0    3
# Banaswadi                 0           0       0  ...      0      0    0
# Bannerghatta Road         0           0       0  ...      0      0    5
# Basavanagudi              0           0       0  ...      0      0    0
#
#                    Tex-Mex  Thai  Tibetan  Turkish  Vegan  Vietnamese  Wraps
# location
# BTM                      0    13       37        7      0           0     11
# Banashankari             0    20        5        0      0           7      0
# Banaswadi                0    10        4        0      0           2      0
# Bannerghatta Road        9    24       16        0      0           5      0
# Basavanagudi             0     4        0        0      0           0      0
#
# [5 rows x 105 columns]

# %% [markdown]
# - Groupingby cuisines by location

# %% [markdown]
# ### Top 20 Cuisines Of Bengaluru

# %%
# Sum the number of restaurants per cuisine
Cuisine_data = neighborhood_cns.sum(axis=0).reset_index()
Cuisine_data.columns = ['Cuisine', 'Number_of_Restaurants']

# Get top 20 cuisines
Top20 = Cuisine_data.sort_values(by='Number_of_Restaurants', ascending=False).head(20)

# Plot
sns.set_style("whitegrid")
plt.figure(figsize=(14,8))
barplot = sns.barplot(x='Cuisine', y='Number_of_Restaurants', data=Top20, palette='viridis')

# Add labels on top of bars for clarity
for p in barplot.patches:
    barplot.annotate(format(p.get_height(), ','),
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='center', va='center',
                     xytext=(0, 5),
                     textcoords='offset points',
                     fontsize=12)

plt.xlabel('Cuisine', fontsize=16)
plt.ylabel('Number of Restaurants', fontsize=16)
plt.title('Top 20 Cuisines on Zomato (Bangalore)', fontsize=22, pad=20)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show("top_20_cuisines")
# Out:
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_1791/3764267680.py:11: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# ✅ Auto-saved: visualizations/top_20_cuisines.png

# %% [markdown]
# - Now it makes sense why The Top 3 cuisines here were the same with High Rating, they've largest fan base.

# %% [markdown]
# ### Top Rated Cuisines of Bengaluru

# %%
# Average Rating per Cuisine
rest_df = df[['cuisines', 'rate']].copy()

# Average rating per cuisine
Cuisine_data_rating = rest_df.groupby('cuisines', as_index=False)['rate'].mean()
Cuisine_data_rating.columns = ['Cuisine', 'Rating']

# Top 30 cuisines by rating
Top30_ratings = Cuisine_data_rating.sort_values(by='Rating', ascending=False).head(30)

# Plot
sns.set_style("whitegrid")
plt.figure(figsize=(16,9))
barplot = sns.barplot(x='Cuisine', y='Rating', data=Top30_ratings, palette='coolwarm')

# Add value labels on top of bars
for p in barplot.patches:
    barplot.annotate(f"{p.get_height():.2f}",
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='center', va='center',
                     xytext=(0, 5),
                     textcoords='offset points',
                     fontsize=11)

plt.xlabel('Cuisine', fontsize=16)
plt.ylabel('Average Rating', fontsize=16)
plt.title('Top 30 Rated Cuisines on Zomato (Bangalore)', fontsize=22, pad=20)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(0, 5)  # Ratings are out of 5
plt.tight_layout()
plt.show()
# Out:
# /var/folders/49/z4dsjwnj3bz30nknl9ffld4h0000gn/T/ipykernel_1791/2096780629.py:14: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# #### Cuisine and rating of a resaurant
# - Does having more number of cuisine mean higher rating of the restaurant? - yes (found latter)

# %%
def fun(x):
    if(type(x) == list):
        return (len(x))
    else:
        return 0
rest_df['no_of_cuisine'] = rest_df['cuisines'].str.split(',').apply(fun)

# %%
rest_df.groupby(['no_of_cuisine'])['rate'].mean()
#rest_df.drop('no_of_cuisine', axis=1, inplace=True)
# Out:
# no_of_cuisine
# 1    3.620499
# 2    3.645548
# 3    3.706357
# 4    3.824714
# 5    3.917793
# 6    3.978989
# 7    4.055181
# 8    3.911515
# Name: rate, dtype: float64

# %% [markdown]
# Answer goes "YES"

# %% [markdown]
# ## Finding->
# American, Italian, Pizza, Biryani, Continental, Chinese, Seafood, Korean were much highly rated. Though North Indian, South Indian, Ice Cream, Mangalorean Beverages, Street Food, Cafe, Indian were the top rated but it is quite obvious for such type of restaurant to be at the top.

# %% [markdown]
# ### top 5 cuisine famous in each of the city

# %%
num_top_venues = 3  # Top 3 cuisines per neighborhood

for hood in neighborhood_cns.index:
    print(f"---- {hood} ----")
    
    # Get the cuisine frequencies for the current neighborhood
    temp = neighborhood_cns.loc[hood].reset_index()
    temp.columns = ['Cuisine', 'Frequency']
    
    # Round frequency values
    temp['Frequency'] = temp['Frequency'].astype(float).round(2)
    
    # Sort descending and select top N cuisines
    top_cuisines = temp.sort_values('Frequency', ascending=False).head(num_top_venues)
    
    print(top_cuisines.reset_index(drop=True))
    print('\n')
# Out:
# ---- BTM ----
#         Cuisine  Frequency
# 0  North Indian     2011.0
# 1       Chinese     1472.0
# 2     Fast Food      805.0
#
#
# ---- Banashankari ----
#         Cuisine  Frequency
# 0  North Indian      273.0
# 1       Chinese      241.0
# 2  South Indian      177.0
#
#
# ---- Banaswadi ----
#         Cuisine  Frequency
# 0       Chinese      197.0
# 1  North Indian      172.0
# 2  South Indian      112.0
#
#
# ---- Bannerghatta Road ----
#         Cuisine  Frequency
# 0  North Indian      589.0
# 1       Chinese      414.0
# 2     Fast Food      248.0
#
#
# ---- Basavanagudi ----
#         Cuisine  Frequency
# 0  South Indian      203.0
# 1  North Indian      162.0
# 2     Fast Food      146.0
#
#
# ---- Basaveshwara Nagar ----
#         Cuisine  Frequency
# 0  North Indian       55.0
# 1       Chinese       46.0
# 2  South Indian       27.0
#
#
# ---- Bellandur ----
#         Cuisine  Frequency
# 0  North Indian      540.0
# 1       Chinese      307.0
# 2       Biryani      207.0
#
#
# ---- Bommanahalli ----
#         Cuisine  Frequency
# 0  North Indian      103.0
# 1       Chinese       72.0
# 2       Biryani       45.0
#
#
# ---- Brigade Road ----
#         Cuisine  Frequency
# 0  North Indian      304.0
# 1       Chinese      294.0
# 2   Continental      244.0
#
#
# ---- Brookefield ----
#         Cuisine  Frequency
# 0  North Indian      222.0
# 1       Chinese      208.0
# 2  South Indian      108.0
#
#
# ---- CV Raman Nagar ----
#         Cuisine  Frequency
# 0  North Indian       26.0
# 1       Chinese       12.0
# 2     Fast Food       12.0
#
#
# ---- Central Bangalore ----
#        Cuisine  Frequency
# 0  Continental        8.0
# 1    Fast Food        6.0
# 2       Burger        3.0
#
#
# ---- Church Street ----
#         Cuisine  Frequency
# 0  North Indian      173.0
# 1   Continental      149.0
# 2          Cafe      124.0
#
#
# ---- City Market ----
#         Cuisine  Frequency
# 0  South Indian       39.0
# 1       Chinese       37.0
# 2  North Indian       33.0
#
#
# ---- Commercial Street ----
#        Cuisine  Frequency
# 0    Fast Food       65.0
# 1       Mithai       60.0
# 2  Street Food       59.0
#
#
# ---- Cunningham Road ----
#         Cuisine  Frequency
# 0  North Indian      224.0
# 1       Chinese      170.0
# 2   Continental      149.0
#
#
# ---- Domlur ----
#         Cuisine  Frequency
# 0  North Indian      171.0
# 1       Chinese      115.0
# 2   Continental       63.0
#
#
# ---- East Bangalore ----
#         Cuisine  Frequency
# 0  North Indian       14.0
# 1       Biryani        8.0
# 2      American        8.0
#
#
# ---- Ejipura ----
#         Cuisine  Frequency
# 0  North Indian      128.0
# 1       Chinese      126.0
# 2     Fast Food       46.0
#
#
# ---- Electronic City ----
#         Cuisine  Frequency
# 0  North Indian      481.0
# 1       Chinese      379.0
# 2  South Indian      186.0
#
#
# ---- Frazer Town ----
#         Cuisine  Frequency
# 0  North Indian      164.0
# 1       Chinese      163.0
# 2     Fast Food      113.0
#
#
# ---- HBR Layout ----
#         Cuisine  Frequency
# 0       Chinese       60.0
# 1  North Indian       43.0
# 2  South Indian       22.0
#
#
# ---- HSR ----
#         Cuisine  Frequency
# 0  North Indian      899.0
# 1       Chinese      631.0
# 2     Fast Food      345.0
#
#
# ---- Hebbal ----
#         Cuisine  Frequency
# 0       Chinese        4.0
# 1  North Indian        4.0
# 2       Biryani        2.0
#
#
# ---- Hennur ----
#         Cuisine  Frequency
# 0  North Indian       56.0
# 1       Chinese       46.0
# 2     Beverages       20.0
#
#
# ---- Hosur Road ----
#         Cuisine  Frequency
# 0  North Indian       61.0
# 1       Chinese       42.0
# 2  South Indian       19.0
#
#
# ---- ITPL Main Road, Whitefield ----
#         Cuisine  Frequency
# 0  North Indian       23.0
# 1      Desserts       22.0
# 2        Bakery       15.0
#
#
# ---- Indiranagar ----
#         Cuisine  Frequency
# 0  North Indian      606.0
# 1       Chinese      417.0
# 2   Continental      359.0
#
#
# ---- Infantry Road ----
#         Cuisine  Frequency
# 0       Chinese       79.0
# 1  North Indian       56.0
# 2     Fast Food       48.0
#
#
# ---- JP Nagar ----
#         Cuisine  Frequency
# 0  North Indian      752.0
# 1       Chinese      522.0
# 2  South Indian      329.0
#
#
# ---- Jalahalli ----
#         Cuisine  Frequency
# 0  South Indian       11.0
# 1       Chinese       10.0
# 2  North Indian        9.0
#
#
# ---- Jayanagar ----
#         Cuisine  Frequency
# 0  North Indian      587.0
# 1       Chinese      512.0
# 2  South Indian      355.0
#
#
# ---- Jeevan Bhima Nagar ----
#         Cuisine  Frequency
# 0  North Indian      111.0
# 1       Chinese       60.0
# 2       Biryani       59.0
#
#
# ---- KR Puram ----
#         Cuisine  Frequency
# 0       Chinese        9.0
# 1  North Indian        6.0
# 2       Biryani        2.0
#
#
# ---- Kaggadasapura ----
#         Cuisine  Frequency
# 0  North Indian       39.0
# 1       Chinese       32.0
# 2  South Indian       18.0
#
#
# ---- Kalyan Nagar ----
#         Cuisine  Frequency
# 0  North Indian      223.0
# 1       Chinese      154.0
# 2   Continental      105.0
#
#
# ---- Kammanahalli ----
#         Cuisine  Frequency
# 0       Chinese      177.0
# 1  North Indian      145.0
# 2     Fast Food      102.0
#
#
# ---- Kanakapura Road ----
#         Cuisine  Frequency
# 0       Chinese       16.0
# 1  North Indian       16.0
# 2  South Indian       12.0
#
#
# ---- Kengeri ----
#        Cuisine  Frequency
# 0         Cafe        9.0
# 1  Continental        9.0
# 2      African        0.0
#
#
# ---- Koramangala ----
#         Cuisine  Frequency
# 0  North Indian       19.0
# 1       Chinese       12.0
# 2       Biryani       11.0
#
#
# ---- Koramangala 1st Block ----
#         Cuisine  Frequency
# 0  North Indian      409.0
# 1       Chinese      245.0
# 2     Fast Food      117.0
#
#
# ---- Koramangala 2nd Block ----
#         Cuisine  Frequency
# 0  North Indian       43.0
# 1       Chinese       36.0
# 2          Cafe       24.0
#
#
# ---- Koramangala 3rd Block ----
#         Cuisine  Frequency
# 0          Cafe       87.0
# 1  North Indian       72.0
# 2       Chinese       50.0
#
#
# ---- Koramangala 4th Block ----
#         Cuisine  Frequency
# 0  North Indian      291.0
# 1       Chinese      242.0
# 2   Continental      196.0
#
#
# ---- Koramangala 5th Block ----
#         Cuisine  Frequency
# 0  North Indian      712.0
# 1       Chinese      674.0
# 2   Continental      537.0
#
#
# ---- Koramangala 6th Block ----
#         Cuisine  Frequency
# 0  North Indian      390.0
# 1       Chinese      307.0
# 2   Continental      179.0
#
#
# ---- Koramangala 7th Block ----
#         Cuisine  Frequency
# 0  North Indian      358.0
# 1       Chinese      253.0
# 2      Desserts      170.0
#
#
# ---- Koramangala 8th Block ----
#         Cuisine  Frequency
# 0       Chinese       76.0
# 1  North Indian       74.0
# 2     Fast Food       63.0
#
#
# ---- Kumaraswamy Layout ----
#         Cuisine  Frequency
# 0       Chinese       86.0
# 1  North Indian       80.0
# 2     Fast Food       34.0
#
#
# ---- Langford Town ----
#         Cuisine  Frequency
# 0   Continental       22.0
# 1  North Indian       22.0
# 2       Italian       22.0
#
#
# ---- Lavelle Road ----
#         Cuisine  Frequency
# 0       Italian      148.0
# 1   Continental      143.0
# 2  North Indian      128.0
#
#
# ---- MG Road ----
#         Cuisine  Frequency
# 0  North Indian      322.0
# 1   Continental      214.0
# 2       Chinese      211.0
#
#
# ---- Magadi Road ----
#         Cuisine  Frequency
# 0  North Indian       10.0
# 1  South Indian       10.0
# 2       Chinese        9.0
#
#
# ---- Majestic ----
#         Cuisine  Frequency
# 0  North Indian       62.0
# 1  South Indian       55.0
# 2       Chinese       51.0
#
#
# ---- Malleshwaram ----
#         Cuisine  Frequency
# 0  North Indian      206.0
# 1       Chinese      153.0
# 2  South Indian      146.0
#
#
# ---- Marathahalli ----
#         Cuisine  Frequency
# 0  North Indian      838.0
# 1       Chinese      573.0
# 2       Biryani      270.0
#
#
# ---- Mysore Road ----
#         Cuisine  Frequency
# 0  South Indian       13.0
# 1  North Indian        9.0
# 2       Chinese        7.0
#
#
# ---- Nagarbhavi ----
#         Cuisine  Frequency
# 0     Fast Food        1.0
# 1       Chinese        1.0
# 2  North Indian        1.0
#
#
# ---- Nagawara ----
#         Cuisine  Frequency
# 0  North Indian       84.0
# 1       Chinese       67.0
# 2       Biryani       42.0
#
#
# ---- New BEL Road ----
#         Cuisine  Frequency
# 0  North Indian      212.0
# 1       Chinese      162.0
# 2          Cafe       94.0
#
#
# ---- North Bangalore ----
#         Cuisine  Frequency
# 0     Fast Food        6.0
# 1       Chinese        6.0
# 2  North Indian        4.0
#
#
# ---- Old Airport Road ----
#         Cuisine  Frequency
# 0  North Indian      180.0
# 1       Chinese      130.0
# 2     Fast Food       61.0
#
#
# ---- Old Madras Road ----
#    Cuisine  Frequency
# 0  Chinese       17.0
# 1  Mughlai        8.0
# 2    Kebab        7.0
#
#
# ---- Peenya ----
#         Cuisine  Frequency
# 0       Chinese        1.0
# 1  North Indian        1.0
# 2       Afghani        0.0
#
#
# ---- RT Nagar ----
#         Cuisine  Frequency
# 0  North Indian       43.0
# 1       Chinese       38.0
# 2  South Indian       18.0
#
#
# ---- Race Course Road ----
#         Cuisine  Frequency
# 0  North Indian       76.0
# 1  South Indian       51.0
# 2   Continental       43.0
#
#
# ---- Rajajinagar ----
#         Cuisine  Frequency
# 0  North Indian      204.0
# 1       Chinese      186.0
# 2  South Indian      166.0
#
#
# ---- Rajarajeshwari Nagar ----
#    Cuisine  Frequency
# 0  Chinese        1.0
# 1  Mexican        1.0
# 2     Thai        1.0
#
#
# ---- Rammurthy Nagar ----
#         Cuisine  Frequency
# 0       Biryani        9.0
# 1  North Indian        9.0
# 2      Desserts        6.0
#
#
# ---- Residency Road ----
#         Cuisine  Frequency
# 0  North Indian      189.0
# 1       Chinese      183.0
# 2      Desserts       89.0
#
#
# ---- Richmond Road ----
#         Cuisine  Frequency
# 0  North Indian      260.0
# 1       Chinese      196.0
# 2  South Indian      108.0
#
#
# ---- Sadashiv Nagar ----
#         Cuisine  Frequency
# 0  North Indian       20.0
# 1       Chinese       17.0
# 2          Cafe       14.0
#
#
# ---- Sahakara Nagar ----
#         Cuisine  Frequency
# 0  South Indian       13.0
# 1     Fast Food       12.0
# 2  North Indian       11.0
#
#
# ---- Sanjay Nagar ----
#         Cuisine  Frequency
# 0  North Indian       22.0
# 1     Fast Food       14.0
# 2       Chinese       13.0
#
#
# ---- Sankey Road ----
#         Cuisine  Frequency
# 0  North Indian       16.0
# 1   Continental       10.0
# 2       Chinese        8.0
#
#
# ---- Sarjapur Road ----
#         Cuisine  Frequency
# 0  North Indian      437.0
# 1       Chinese      244.0
# 2       Biryani      138.0
#
#
# ---- Seshadripuram ----
#         Cuisine  Frequency
# 0  North Indian       73.0
# 1       Chinese       57.0
# 2   Continental       31.0
#
#
# ---- Shanti Nagar ----
#         Cuisine  Frequency
# 0  North Indian      155.0
# 1       Chinese      117.0
# 2     Fast Food       85.0
#
#
# ---- Shivajinagar ----
#         Cuisine  Frequency
# 0  North Indian      148.0
# 1  South Indian      106.0
# 2       Chinese       97.0
#
#
# ---- South Bangalore ----
#         Cuisine  Frequency
# 0     Fast Food       30.0
# 1  North Indian       24.0
# 2      Desserts       23.0
#
#
# ---- St. Marks Road ----
#         Cuisine  Frequency
# 0  North Indian      121.0
# 1     Fast Food       74.0
# 2       Chinese       61.0
#
#
# ---- Thippasandra ----
#         Cuisine  Frequency
# 0  North Indian       55.0
# 1       Chinese       37.0
# 2  South Indian       27.0
#
#
# ---- Ulsoor ----
#         Cuisine  Frequency
# 0  North Indian      312.0
# 1       Chinese      216.0
# 2          Cafe      175.0
#
#
# ---- Uttarahalli ----
#         Cuisine  Frequency
# 0       Chinese        6.0
# 1  North Indian        6.0
# 2  South Indian        4.0
#
#
# ---- Varthur Main Road, Whitefield ----
#         Cuisine  Frequency
# 0  North Indian       37.0
# 1       Chinese       24.0
# 2       Biryani       20.0
#
#
# ---- Vasanth Nagar ----
#         Cuisine  Frequency
# 0  North Indian      105.0
# 1       Chinese       82.0
# 2          Cafe       55.0
#
#
# ---- Vijay Nagar ----
#         Cuisine  Frequency
# 0  North Indian       30.0
# 1  South Indian       30.0
# 2       Chinese       29.0
#
#
# ---- West Bangalore ----
#         Cuisine  Frequency
# 0  Healthy Food        3.0
# 1       Biryani        2.0
# 2   Continental        2.0
#
#
# ---- Whitefield ----
#         Cuisine  Frequency
# 0  North Indian      804.0
# 1       Chinese      450.0
# 2       Biryani      264.0
#
#
# ---- Wilson Garden ----
#         Cuisine  Frequency
# 0  North Indian      113.0
# 1       Chinese       84.0
# 2  South Indian       40.0
#
#
# ---- Yelahanka ----
#         Cuisine  Frequency
# 0  South Indian        4.0
# 1        Kerala        2.0
# 2       Seafood        2.0
#
#
# ---- Yeshwantpur ----
#         Cuisine  Frequency
# 0  North Indian       66.0
# 1       Chinese       60.0
# 2  South Indian       33.0

# %% [markdown]
# Visualizing the same using ChatGPT code->

# %%
# Create a dataframe to hold only the top 3 cuisines per neighborhood
top_cuisines_per_hood = pd.DataFrame()

num_top_venues = 3

for hood in neighborhood_cns.index:
    temp = neighborhood_cns.loc[hood].reset_index()
    temp.columns = ['Cuisine', 'Frequency']
    temp['Frequency'] = temp['Frequency'].astype(float)
    top = temp.sort_values('Frequency', ascending=False).head(num_top_venues)
    top['Neighborhood'] = hood
    top_cuisines_per_hood = pd.concat([top_cuisines_per_hood, top], ignore_index=True)

# Pivot the dataframe for heatmap
heatmap_data = top_cuisines_per_hood.pivot(index='Neighborhood', columns='Cuisine', values='Frequency').fillna(0)

# Plot heatmap
plt.figure(figsize=(15, 12))
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="YlGnBu", linewidths=0.5)
plt.title("Top 3 Cuisines per Neighborhood", fontsize=20, pad=20)
plt.xlabel("Cuisine", fontsize=15)
plt.ylabel("Neighborhood", fontsize=15)
plt.show("top_cuisines_heatmap")
# Out:
# ✅ Auto-saved: visualizations/top_cuisines_heatmap.png

# %% [markdown]
# ### top 3 cuisines per neighborhood

# %%
num_top_venues = 3

fig, ax = plt.subplots(figsize=(12, len(neighborhood_cns)*0.5))

y_pos = np.arange(len(neighborhood_cns))
bar_height = 0.2
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']

for i, hood in enumerate(neighborhood_cns.index):
    top_cuisines = neighborhood_cns.loc[hood].sort_values(ascending=False).head(num_top_venues)
    for j, (cuisine, freq) in enumerate(top_cuisines.items()):
        ax.barh(y_pos[i] + j*bar_height, freq, height=bar_height, color=colors[j])
        ax.text(freq + 1, y_pos[i] + j*bar_height, str(freq), va='center', fontsize=8)

ax.set_yticks(y_pos + bar_height)
ax.set_yticklabels(neighborhood_cns.index)
ax.set_xlabel("Number of Restaurants")
ax.set_title("Top 3 Cuisines per Neighborhood", fontsize=16)
plt.tight_layout()
plt.show("top_cuisines_barplot")
# Out:
# ✅ Auto-saved: visualizations/top_cuisines_barplot.png

# %% [markdown]
# ### Cuisine WordCloud

# %%
# Assuming neighborhood_cns has neighborhoods as index and cuisines as columns
cuisine_grouped = neighborhood_cns.groupby(neighborhood_cns.index).sum()
# Sum frequencies of each cuisine across all neighborhoods
cuisine_freq = cuisine_grouped.iloc[:, 1:].sum(axis=0).to_dict()

# Generate wordcloud
wordcloud = WordCloud(width=1200, height=800, relative_scaling=0.5, background_color='white').generate_from_frequencies(cuisine_freq)

# Plot
plt.figure(figsize=(12,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show("cuisine_wordcloud")
# Out:
# ✅ Auto-saved: visualizations/cuisine_wordcloud.png

# %%
# Top 10 cuisines
top_10_cuisines = df['cuisines'].value_counts().sort_values(ascending=False)[:10]

# Plotting
plt.figure(figsize=(4, 4))
plt.pie(top_10_cuisines, labels=top_10_cuisines.index, autopct='%1.1f%%', counterclock=False)
plt.title('Top 10 Cuisines in the Dataset', fontweight='bold')
plt.savefig("visualizations/top_10_cuisines_piechart.png")
plt.show()

# %% [markdown]
# #### EDA done!
# - we will import this dataset for further process -> PreProcessing, Model Building etc.

# %%
# df.head(1)

# %% [markdown]
# Saving final dataset in artiacts folder (will .dvc it later)

# %%
import joblib
joblib.dump(df.reset_index(drop=True), "/Users/mac/Desktop/Desktop_Files/Projects/Zomato Restaurant Rating Prediction/artifacts/EDA_final_cleaned.pkl")
# Out:
# ['/Users/mac/Desktop/Desktop_Files/Projects/Zomato Restaurant Rating Prediction/artifacts/EDA_final_cleaned.pkl']
